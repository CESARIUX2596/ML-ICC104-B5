# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[(df["Sex"] == "female") & (df["Survived"] == 1) & (df["Age"] > 50)].shape[0]
# Out:
# 16

# %%
df[df["Survived"] == 0]["Fare"].median()
# Out:
# np.float64(10.5)

# %%
(df[df["Pclass"] == 3]["Survived"].mean() * 100).round(2)
# Out:
# np.float64(24.24)

# %%
df["Embarked"].value_counts(dropna=False)
# Out:
# Embarked
# S      644
# C      168
# Q       77
# NaN      2
# Name: count, dtype: int64

# %%
df[(df["Sex"] == "male") & (df["Survived"] == 1)]["Age"].mean() #hombres
# Out:
# np.float64(27.276021505376345)

# %%
df[(df["Sex"] == "female") & (df["Survived"] == 1)]["Age"].mean()
# Out:
# np.float64(28.84771573604061)

# %%
df[df["Cabin"].isna() & (df["Survived"] == 0)].shape[0]
# Out:
# 481

# %%
df[(df["SibSp"] == 0) & (df["Parch"] == 0)]["Survived"].mean() * 100
# Out:
# np.float64(30.353817504655495)

# %%
df[(df["SibSp"] + df["Parch"]) > 0]["Survived"].mean() * 100
# Out:
# np.float64(50.56497175141242)

# %%
abs((df[(df["SibSp"] == 0) & (df["Parch"] == 0)]["Survived"].mean() * 100) - (df[(df["SibSp"] + df["Parch"]) > 0]["Survived"].mean() * 100))
# Out:
# np.float64(20.211154246756927)

# %%
df.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df[df["Age"] < 18].shape[0]
# Out:
# 113

# %%
df[df["Age"] < 18]["Survived"].mean() * 100
# Out:
# np.float64(53.98230088495575)

# %%
df["Fare"].corr(df["Pclass"])
# Out:
# np.float64(-0.5494996199439074)

# %%
df["Age"].plot(kind="hist", bins=20, title="Age Distribution")
# Out:
# <Axes: title={'center': 'Age Distribution'}, ylabel='Frequency'>

# %%
df.groupby(["Sex", "Survived"]).size().unstack().plot(kind="bar")
# Out:
# <Axes: xlabel='Sex'>
